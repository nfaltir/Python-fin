# %% [markdown]
# <a href="https://colab.research.google.com/github/nfaltir/Python-fin/blob/main/stock_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style

# %% [markdown]
# **Get average price movements by timeframe**

# %%
timeFrame = ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
#stock = str(input("\nPlease enter the stock ticker:"))
stockObj = yf.Ticker("SQ")
for var in timeFrame:
  stockHistory = stockObj.history(period=var)
  df = pd.DataFrame(stockHistory)
  avgPrice = sum(df['Close'])/len(df['Close'])
  print(var,"average price:",round(avgPrice,2))
  continue

minPrice = min(df['Close'])
maxPrice = max(df['Close'])

print("\nLowest Price:",round(minPrice,2))
print("Max Price:", round(maxPrice,2))
# Out:
# 1d average price: 222.88
# 5d average price: 224.83
# 1mo average price: 226.73
# 3mo average price: 206.03
# 6mo average price: 180.07
# 1y average price: 129.82
# 2y average price: 99.3
# 5y average price: 60.06
# 10y average price: 58.47
# ytd average price: 228.54
# max average price: 58.47
#
# Lowest Price: 8.37
# Max Price: 241.58

# %% [markdown]
# **Generate Charts**

# %%
stock = "SQ"

stockObj = yf.Ticker(stock)



y = "\n[***** 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max============*****]\n"


time = "max"
timeFrame = stockObj.history(period=time)



df = pd.DataFrame(timeFrame)
plt.style.use('bmh')
plt.ylabel('Price ($USD)',fontsize=15)
plt.xlabel('Date',fontsize=15)

df['Close'].plot(figsize=(12,6))




plt.title("Price History", fontsize=25)
plt.show()

# %% [markdown]
# **Generate All general information for stock**

# %%
sTicker = "SQ"

# Retruns UPPER case ticker symbol
stock = sTicker.upper()
stockObj = yf.Ticker(stock)
# General Data
genData = stockObj.info
#df = pd.DataFrame(genData)

for metrics in genData.items(): 
    metrics = (str(metrics).replace("(","").replace(")", "").replace(",",":").replace("'",""))
    print(metrics)
# Out:
# zip: 94103
# sector: Technology
# fullTimeEmployees: 3835
# ...
